# %%
# Date: 23 March, 2024
# CSC461 – Assignment2 – IDS – Data-Visualization
# Badar Munir
# Sp20-Bse-068
#The Diamond dataset visualization.

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('diamonds.csv')

filtered_df = df[(df['clarity'] == 'SI2') & (df['color'] == 'E')].copy()

filtered_df['cut_color'] = filtered_df['cut'].map(cut_colors)

plt.figure(figsize=(10, 6))
plt.scatter(filtered_df['carat'], filtered_df['price'], c=filtered_df['cut_color'], alpha=0.5)

# Creating a custom legend
from matplotlib.lines import Line2D
legend_elements = [Line2D([0], [0], marker='o', color='w', label=cut, 
                          markerfacecolor=color, markersize=10) for cut, color in cut_colors.items()]
plt.legend(handles=legend_elements, title='Diamond Cut')

# Enhancing the plot
plt.title('Relationship Between Carat and Price for Diamonds (Clarity SI2 & Color E)')
plt.xlabel('Carat')
plt.ylabel('Price ($)')
plt.grid(True)
plt.tight_layout()

# Show plot
plt.show()
